# %%
import duckdb
import os

# 1. Identify the Project Root (finds 'triangle-spatial-data-engine' folder)
# This makes paths robust across different environments
root = os.path.abspath(os.path.join(os.getcwd(), "../../")) # Adjust based on notebook location
db_path = os.path.join(root, "data/triangle_engine.db")

# 2. Connect to the Single Source of Truth
con = duckdb.connect(db_path)

# 3. Standard Spatial Setup
con.execute("INSTALL spatial; LOAD spatial;")

print(f"Engine Connected: {db_path}")
# Out:
# Engine Connected: /workspaces/triangle-spatial-data-engine/data/triangle_engine.db

# %%
# Project-specific paths
proj_dir = os.path.join(root, "projects/01_food_desert_transit")
bronze_dir = os.path.join(proj_dir, "data/bronze")
silver_dir = os.path.join(proj_dir, "data/silver")

print(f"Project 01 Context Set.\nBronze: {bronze_dir}")
# Out:
# Project 01 Context Set.
# Bronze: /workspaces/triangle-spatial-data-engine/projects/01_food_desert_transit/data/bronze

# %%
# Create Views using absolute paths to avoid IOErrors
con.execute(f"CREATE OR REPLACE VIEW bus_stops AS SELECT * FROM '{bronze_dir}/bus_stops.parquet'")
con.execute(f"CREATE OR REPLACE VIEW grocery_stores AS SELECT * FROM '{bronze_dir}/grocery_stores.parquet'")

print("Spatial Views Mounted.")
# Out:
# Spatial Views Mounted.

# %%
# Audit the structure of Bus Stops 
print("--- Bus Stops Schema ---")
con.execute("DESCRIBE bus_stops;").df()
# Out:
# --- Bus Stops Schema ---
#             column_name            column_type null   key default extra
# 0              OBJECTID                INTEGER  YES  None    None  None
# 1             Stop_Code                INTEGER  YES  None    None  None
# 2               Stop_ID                INTEGER  YES  None    None  None
# 3             Stop_Name                VARCHAR  YES  None    None  None
# 4                Street                VARCHAR  YES  None    None  None
# ..                  ...                    ...  ...   ...     ...   ...
# 120    Construction_Set                VARCHAR  YES  None    None  None
# 121  Bench_Install_Year                VARCHAR  YES  None    None  None
# 122          SWS_Pickup                VARCHAR  YES  None    None  None
# 123           Timepoint                VARCHAR  YES  None    None  None
# 124            geometry  GEOMETRY('EPSG:4326')  YES  None    None  None
#
# [125 rows x 6 columns]

# %%
# Audit the structure of Grocery Stores
print("\n--- Grocery Stores Schema ---")
con.execute("DESCRIBE grocery_stores;").df()
# Out:
# --- Grocery Stores Schema ---
#             column_name                                        column_type  \
# 0                  type                                            VARCHAR
# 1                    id                                             BIGINT
# 2                   lat                                             DOUBLE
# 3                   lon                                             DOUBLE
# 4                  tags  STRUCT("addr:city" VARCHAR, "addr:country" VAR...
# ..                  ...                                                ...
# 67         diet:organic                                            VARCHAR
# 68         diet:seafood                                            VARCHAR
# 69           diet:vegan                                            VARCHAR
# 70      diet:vegetarian                                            VARCHAR
# 71  payment:contactless                                            VARCHAR
#
#    null   key default extra
# 0   YES  None    None  None
# 1   YES  None    None  None
# 2   YES  None    None  None
# 3   YES  None    None  None
# 4   YES  None    None  None
# ..  ...   ...     ...   ...
# 67  YES  None    None  None
# 68  YES  None    None  None
# 69  YES  None    None  None
# 70  YES  None    None  None
# 71  YES  None    None  None
#
# [72 rows x 6 columns]

# %% [markdown]
# ### Data Exploration & Validation Strategy
#
# Before performing any transformations or moving data from bronze to silver, I am conducting an audit of the raw files. A schema definition only shows the shape of the data; it does not reveal the health or the actual content.
#
# **Approach:**
#
# * **Individualized Inspection:** Splitting the audit into separate cells to isolate outputs and avoid information overload.
# * **Bus Stop Integrity:** Verifying the legitimacy of the spatial points. I need to confirm the record counts and ensure the dataset isn't riddled with anomalies that would break future analysis.
# * **Grocery Store Deconstruction:** With 72 columns, most of this dataset is noise. I need to explore the nested tags structure to identify which attributes are actually populated and relevant.

# %%
# 
con.sql("SELECT * FROM bus_stops LIMIT 5")
# Out:
# ┌──────────┬───────────┬─────────┬───────────────────────────────────────────────┬─────────────────┬─────────────────────────────────┬──────────┬────────────────────┬────────────────────┬──────────┬──────────────────┬───────────┬────────────┬───────────┬────────────┬──────────┬─────────────┬──────────┬─────────┬─────────┬──────────────┬───────────────┬─────────┬────────────┬─────────────┬───────────┬────────────────┬─────────────────┬─────────────┬─────────────┬──────────┬───────────┬──────────┬───────────────┬───────────┬──────────────┬──────────┬───────────┬────────────┬───────────┬───────────────┬───────────┬──────────┬─────────┬─────────┬──────────────┬────────────────┬────────────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬───────────┬────────────┬─────────────┬───────────────┬────────────────────────────────┬───────────────┬────────────────────────────────┬──────────────┬───────────┬──────────┬──────────────────┬───────────────────┬─────────────┬──────────────────────────────────────┬─────────┬────────────────┬───────────┬─────────────────┬─────────┬──────────────┬────────────┬──────────────────┬────────────────────┬────────────┬───────────┬────────────────────────────────────────────┐
# │ OBJECTID │ Stop_Code │ Stop_ID │                   Stop_Name                   │     Street      │          Cross_Street           │ Position │      Stop_Lat      │      Stop_Lon      │ Downtown │ Council_District │ Sign_Crew │ Road_Maint │ GoRaleigh │ GoTriangle │ Wolfline │ Wake_Forest │ GoDurham │ GoCary  │ Shelter │ Shelter_Type │ Shelter_Count │  Bench  │ Bench_Type │ Bench_Count │ Trash_Can │ Trash_Can_Type │ Trash_Can_Count │ Landing_Pad │ Amenity_Pad │ Pad_Size │ Bike_Rack │ Lighting │ Lighting_Type │ Real_Time │ USB_Charging │ Sidewalk │ Crosswalk │ Ped_Signal │ Curb_Ramp │ ADA_Compliant │ Bike_Lane │ Greenway │   Art   │ Project │ Project_Type │ Project_Status │ Project_Target │   R1    │   R2    │   R2L   │   R3    │   R4    │   R5    │   R6    │   R7    │   R7L   │   R8    │   R8L   │   R9    │   R10   │   R11   │  R11L   │   R12   │   R13   │   R14   │   R15   │  R15L   │   R16   │   R18   │  R18S   │   R19   │   R20   │   R21   │   R22   │   R23   │  R23L   │   R24   │  R24L   │   R25   │  R25L   │   R26   │   R27   │   R28   │   R29   │   R31   │   R32   │   R33   │   R34   │   R36   │  R40X   │  R55X   │  R70X   │  R401X  │ R_Line  │   WRX   │   WFL   │   FRX   │   ZWX   │ Boardings │ Alightings │ Facility_ID │ CreationDate  │            Creator             │   EditDate    │             Editor             │ Project_Lead │ Sign_Type │ Bus_Zone │ Project_Complete │ Ridership_Updated │ Landscaping │               GlobalID               │   R17   │ EmergencyPhone │ Adoptable │ Adoption_Status │ Status  │ Last_Cleaned │ Year_Built │ Construction_Set │ Bench_Install_Year │ SWS_Pickup │ Timepoint │                  geometry                  │
# │  int32   │   int32   │  int32  │                    varchar                    │     varchar     │             varchar             │ varchar  │       double       │       double       │ varchar  │     varchar      │  varchar  │  varchar   │  varchar  │  varchar   │ varchar  │   varchar   │ varchar  │ varchar │ varchar │   varchar    │    double     │ varchar │  varchar   │   double    │  varchar  │    varchar     │     double      │   varchar   │   varchar   │ varchar  │  varchar  │ varchar  │    varchar    │  varchar  │   varchar    │ varchar  │  varchar  │  varchar   │  varchar  │    varchar    │  varchar  │ varchar  │ varchar │ varchar │   varchar    │    varchar     │    varchar     │ varchar │ varchar │ varchar │ varchar │ varchar │ varchar │ varchar │ varchar │ varchar │ varchar │ varchar │ varchar │ varchar │ varchar │ varchar │ varchar │ varchar │ varchar │ varchar │ varchar │ varchar │ varchar │ varchar │ varchar │ varchar │ varchar │ varchar │ varchar │ varchar │ varchar │ varchar │ varchar │ varchar │ varchar │ varchar │ varchar │ varchar │ varchar │ varchar │ varchar │ varchar │ varchar │ varchar │ varchar │ varchar │ varchar │ varchar │ varchar │ varchar │ varchar │ varchar │  double   │   double   │   varchar   │     int64     │            varchar             │     int64     │            varchar             │   varchar    │  varchar  │ varchar  │      double      │      double       │   varchar   │               varchar                │ varchar │    varchar     │  varchar  │     varchar     │ varchar │    double    │  varchar   │     varchar      │      varchar       │  varchar   │  varchar  │           geometry('epsg:4326')            │
# ├──────────┼───────────┼─────────┼───────────────────────────────────────────────┼─────────────────┼─────────────────────────────────┼──────────┼────────────────────┼────────────────────┼──────────┼──────────────────┼───────────┼────────────┼───────────┼────────────┼──────────┼─────────────┼──────────┼─────────┼─────────┼──────────────┼───────────────┼─────────┼────────────┼─────────────┼───────────┼────────────────┼─────────────────┼─────────────┼─────────────┼──────────┼───────────┼──────────┼───────────────┼───────────┼──────────────┼──────────┼───────────┼────────────┼───────────┼───────────────┼───────────┼──────────┼─────────┼─────────┼──────────────┼────────────────┼────────────────┼─────────┼─────────┼─────────┼─────────┼─────────┼─────────┼─────────┼─────────┼─────────┼─────────┼─────────┼─────────┼─────────┼─────────┼─────────┼─────────┼─────────┼─────────┼─────────┼─────────┼─────────┼─────────┼─────────┼─────────┼─────────┼─────────┼─────────┼─────────┼─────────┼─────────┼─────────┼─────────┼─────────┼─────────┼─────────┼─────────┼─────────┼─────────┼─────────┼─────────┼─────────┼─────────┼─────────┼─────────┼─────────┼─────────┼─────────┼─────────┼─────────┼─────────┼─────────┼───────────┼────────────┼─────────────┼───────────────┼────────────────────────────────┼───────────────┼────────────────────────────────┼──────────────┼───────────┼──────────┼──────────────────┼───────────────────┼─────────────┼──────────────────────────────────────┼─────────┼────────────────┼───────────┼─────────────────┼─────────┼──────────────┼────────────┼──────────────────┼────────────────────┼────────────┼───────────┼────────────────────────────────────────────┤
# │        1 │      1201 │    1201 │ Hillsborough St at Mayo St                    │ Hillsborough St │ Mayo St                         │ Far      │   35.7815446214905 │ -78.65335582840319 │ No       │ D                │ C         │ Municipal  │ Yes       │ No         │ No       │ No          │ No       │ No      │ No      │              │           0.0 │ No      │            │         0.0 │ No        │ NULL           │             0.0 │ No          │ No          │          │ No        │ None     │ NULL          │ No        │ No           │ Yes      │ Yes       │ Yes        │ Yes       │ Yes           │ Yes       │ No       │ No      │         │ NULL         │ NULL           │                │ No      │ No      │ No      │ No      │ Yes     │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │       3.0 │        5.0 │ 1201        │ 1595942859407 │ justin.greco@raleighnc.gov_ral │ 1768934407873 │ reese.berman@raleighnc.gov_ral │              │ GoRaleigh │ Yes      │             NULL │  -2209161589000.0 │ NULL        │ 35785dd5-80f7-45bf-ad73-c8b8049d3c37 │ No      │ NULL           │ No        │ Available       │ Active  │         NULL │ NULL       │ NULL             │ NULL               │ NULL       │ NULL      │ POINT (-78.6533558284032 35.7815446216135) │
# │        2 │      1284 │    1284 │ Wilmington St at Cabarrus St                  │ Wilmington St   │ Cabarrus St                     │ Far      │          35.774697 │         -78.638353 │ Yes      │ C                │ E         │ Municipal  │ Yes       │ Yes        │ No       │ No          │ No       │ No      │ Yes     │ R-Line       │           1.0 │ No      │ NULL       │         0.0 │ No        │ NULL           │             0.0 │ No          │ No          │          │ No        │ Some     │ Street        │ No        │ No           │ Yes      │ Yes       │ Yes        │ Yes       │ Yes           │ Yes       │ No       │ Yes     │ R-Line  │ Shelter      │ Complete       │                │ No      │ No      │ No      │ No      │ No      │ Yes     │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ Yes     │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ Yes     │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ Yes     │ No      │ No      │ No      │ No      │      17.0 │       69.0 │ 1284        │ 1595942859407 │ justin.greco@raleighnc.gov_ral │ 1768934408459 │ reese.berman@raleighnc.gov_ral │ GR           │ GoRaleigh │ No       │             NULL │  -2209161589000.0 │ Compliant   │ 1b52f78b-d06e-4b11-9520-898f8dce2b92 │ No      │ NULL           │ Yes       │ Available       │ Active  │         NULL │ NULL       │ NULL             │ NULL               │ NULL       │ NULL      │ POINT (-78.6383530001644 35.7746969996616) │
# │        4 │      1539 │    1539 │ Hammond Rd at Chapanoke Rd (SECU)             │ Hammond Rd      │ Chapanoke Rd (SECU)             │          │ 35.735500000511884 │ -78.64039999928718 │ No       │ D                │ D         │ NCDOT      │ Yes       │ No         │ No       │ No          │ No       │ No      │ No      │              │           0.0 │ No      │            │         0.0 │ No        │ NULL           │             0.0 │ No          │ No          │          │ No        │          │               │ No        │ No           │ Yes      │ Yes       │ Yes        │ Yes       │ No            │           │ No       │ No      │         │ NULL         │ NULL           │                │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ Yes     │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │       1.0 │        3.0 │ 1539        │ 1595942859407 │ justin.greco@raleighnc.gov_ral │ 1768934408862 │ reese.berman@raleighnc.gov_ral │              │ GoRaleigh │ No       │             NULL │  -2209161589000.0 │ NULL        │ fe50eac8-5ec8-4167-bd46-f93c2ca194bc │ No      │ NULL           │ No        │ Available       │ Active  │         NULL │ NULL       │ NULL             │ NULL               │ NULL       │ NULL      │ POINT (-78.6403999992872 35.7355000007599) │
# │        5 │      1540 │    1540 │ Hammond Rd at Chapanoke Rd (Detention Center) │ Hammond Rd      │ Chapanoke Rd (Detention Center) │          │  35.73544912969152 │ -78.63995723226006 │ No       │ D                │ D         │ NCDOT      │ Yes       │ No         │ No       │ No          │ No       │ No      │ No      │              │           0.0 │ No      │            │         0.0 │ No        │ NULL           │             0.0 │ No          │ No          │          │ No        │          │               │ No        │ No           │ Yes      │ Yes       │ Yes        │ Yes       │ No            │           │ No       │ No      │         │ Shelter      │ Eligible       │ NULL           │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ Yes     │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │       5.0 │        2.0 │ 1540        │ 1595942859407 │ justin.greco@raleighnc.gov_ral │ 1768934409170 │ reese.berman@raleighnc.gov_ral │              │ GoRaleigh │ No       │             NULL │  -2209161589000.0 │ NULL        │ 7d4417dc-fb21-4284-bb89-849d875aae5a │ No      │ NULL           │ No        │ Available       │ Active  │         NULL │ NULL       │ NULL             │ NULL               │ NULL       │ NULL      │ POINT (-78.6399572322601 35.7354491293536) │
# │        6 │      1703 │    1703 │ Hillsborough St at S Dawson St                │ Hillsborough St │ S Dawson St                     │ Near     │           35.78047 │          -78.64365 │ Yes      │ D                │ E         │ Municipal  │ Yes       │ No         │ No       │ No          │ No       │ No      │ No      │ NULL         │           0.0 │ No      │ NULL       │         0.0 │ NULL      │ NULL           │             0.0 │ No          │ No          │          │ No        │          │               │ No        │ No           │ Yes      │ Yes       │ Yes        │ Yes       │ No            │ Yes       │ No       │ No      │         │ NULL         │ NULL           │                │ No      │ No      │ No      │ No      │ Yes     │ No      │ No      │ No      │ No      │ Yes     │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │ No      │       2.0 │        9.0 │ 1703        │ 1595942859407 │ justin.greco@raleighnc.gov_ral │ 1768934409519 │ reese.berman@raleighnc.gov_ral │              │ GoRaleigh │ No       │             NULL │  -2209161589000.0 │ NULL        │ 180dac20-51ab-4ea3-b577-043c29315272 │ No      │ NULL           │ No        │ Available       │ Active  │         NULL │ NULL       │ NULL             │ NULL               │ NULL       │ NULL      │ POINT (-78.6436499997805 35.7804699997943) │
# └──────────┴───────────┴─────────┴───────────────────────────────────────────────┴─────────────────┴─────────────────────────────────┴──────────┴────────────────────┴────────────────────┴──────────┴──────────────────┴───────────┴────────────┴───────────┴────────────┴──────────┴─────────────┴──────────┴─────────┴─────────┴──────────────┴───────────────┴─────────┴────────────┴─────────────┴───────────┴────────────────┴─────────────────┴─────────────┴─────────────┴──────────┴───────────┴──────────┴───────────────┴───────────┴──────────────┴──────────┴───────────┴────────────┴───────────┴───────────────┴───────────┴──────────┴─────────┴─────────┴──────────────┴────────────────┴────────────────┴─────────┴─────────┴─────────┴─────────┴─────────┴─────────┴─────────┴─────────┴─────────┴─────────┴─────────┴─────────┴─────────┴─────────┴─────────┴─────────┴─────────┴─────────┴─────────┴─────────┴─────────┴─────────┴─────────┴─────────┴─────────┴─────────┴─────────┴─────────┴─────────┴─────────┴─────────┴─────────┴─────────┴─────────┴─────────┴─────────┴─────────┴─────────┴─────────┴─────────┴─────────┴─────────┴─────────┴─────────┴─────────┴─────────┴─────────┴─────────┴─────────┴─────────┴─────────┴───────────┴────────────┴─────────────┴───────────────┴────────────────────────────────┴───────────────┴────────────────────────────────┴──────────────┴───────────┴──────────┴──────────────────┴───────────────────┴─────────────┴──────────────────────────────────────┴─────────┴────────────────┴───────────┴─────────────────┴─────────┴──────────────┴────────────┴──────────────────┴────────────────────┴────────────┴───────────┴────────────────────────────────────────────┘
